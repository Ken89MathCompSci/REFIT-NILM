# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/REFIT-NILM/blob/master/9-September-2026-First-Run-House-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/REFIT-NILM
# Out:
# /content/REFIT-NILM

# %%
# %pwd
# Out:
# '/content/REFIT-NILM'

# %%
# SVM baseline
# !python Sep-2026-House-3-scripts/nilm_sfra_svm_house3.py
# Out:
# Loading APR-REFIT-House3-dataset from '/content/REFIT-NILM/Sep-2026-House-3-scripts/../APR-REFIT-House3-dataset' ...
#   train : 324,000 rows  2015-02-10 -> 2015-03-11
#   val   :  75,600 rows  2015-03-12 -> 2015-03-18
#   test  :  75,600 rows  2015-03-19 -> 2015-03-25
#
# Adaptive thresholds (train-locked):
#   dishwasher         21.0 W
#   fridge             97.0 W
#   microwave          28.0 W
#   washing_machine    21.0 W
#
# Computing features ...
#   Train: 324,000 samples -> using 20,000 for SVM
#   Test : 75,600 samples
#
#   [dishwasher]
#     Train ON%=4.4%  Test ON%=3.2%
#     class_weight: raw=21.6  clamped=10.0
#   [fridge]
#     Train ON%=10.6%  Test ON%=6.1%
#     class_weight: raw=8.4  clamped=8.4
#   [microwave]
#     Train ON%=0.6%  Test ON%=0.1%
#     class_weight: raw=177.6  clamped=10.0
#   [washing_machine]
#     Train ON%=5.3%  Test ON%=1.7%
#     class_weight: raw=17.8  clamped=10.0
#
# ...

# %%
# Baselines (uniform 10W threshold)
# !python Sep-2026-House-3-scripts/test_gru_refit_house3_dataset.py
# Out:
# Testing GRU on APR-REFIT-House3-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House3-dataset
#   Train: 2015-02-10 00:00:00+00:00 to 2015-03-11 23:59:52+00:00  (324,000 rows)
#   Val: 2015-03-12 00:00:00+00:00 to 2015-03-18 23:59:52+00:00  (75,600 rows)
#   Test: 2015-03-19 00:00:00+00:00 to 2015-03-25 23:59:52+00:00  (75,600 rows)
#
# ...
# Testing GRU on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting GRU training for dishwasher...
# Epoch 1/80: 100% 2025/2025 [00:03<00:00, 559.56it/s, loss=0.000117]
# Epoch 1/80, Train Loss: 0.000142, Val Loss: 0.000068, Val MAE: 123.75, Val SAE: 102.99, Val F1: 0.1382, Val Precision: 0.0742, Val Recall: 0.9982
# ...

# %%
# Gated v2 models (adaptive thresholds: dishwasher=21W, fridge=97W, microwave=28W, washing_machine=21W)
# !python Sep-2026-House-3-scripts/test_resnet_refit_house3_dataset_v2.py
# Out:
# Testing Gated ResNet v2 on APR-REFIT-House3-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House3-dataset
#   Train: 2015-02-10 00:00:00+00:00 to 2015-03-11 23:59:52+00:00  (324,000 rows)
#   Val: 2015-03-12 00:00:00+00:00 to 2015-03-18 23:59:52+00:00  (75,600 rows)
#   Test: 2015-03-19 00:00:00+00:00 to 2015-03-25 23:59:52+00:00  (75,600 rows)
#
#   Adaptive thresholds (train-locked, replaces the baseline scripts' uniform 10W):
#     dishwasher       21.0W
#     fridge           97.0W
#     microwave        28.0W
#     washing_machine  21.0W
#
# ...
# Testing Gated ResNet on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...  (threshold=21.0W)
#   Gate target: on=4.7%  pos_weight=20.4  thr_scaled=0.0007
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting Gated ResNet training for dishwasher...
# ...

# %%
# !python Sep-2026-House-3-scripts/test_tcn_refit_house3_dataset_v2.py
# Out:
# Testing Gated TCN v2 on APR-REFIT-House3-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House3-dataset
#   Train: 2015-02-10 00:00:00+00:00 to 2015-03-11 23:59:52+00:00  (324,000 rows)
#   Val: 2015-03-12 00:00:00+00:00 to 2015-03-18 23:59:52+00:00  (75,600 rows)
#   Test: 2015-03-19 00:00:00+00:00 to 2015-03-25 23:59:52+00:00  (75,600 rows)
#
#   Adaptive thresholds (train-locked, replaces the baseline scripts' uniform 10W):
#     dishwasher       21.0W
#     fridge           97.0W
#     microwave        28.0W
#     washing_machine  21.0W
#
# ...
# Testing Gated TCN on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...  (threshold=21.0W)
#   Gate target: on=4.7%  pos_weight=20.4  thr_scaled=0.0007
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting Gated TCN training for dishwasher...
# ...

# %%
# !python Sep-2026-House-3-scripts/test_lstm_refit_house3_dataset.py
# Out:
# Testing LSTM on APR-REFIT-House3-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House3-dataset
#   Train: 2015-02-10 00:00:00+00:00 to 2015-03-11 23:59:52+00:00  (324,000 rows)
#   Val: 2015-03-12 00:00:00+00:00 to 2015-03-18 23:59:52+00:00  (75,600 rows)
#   Test: 2015-03-19 00:00:00+00:00 to 2015-03-25 23:59:52+00:00  (75,600 rows)
#
# ...
# Testing LSTM on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting LSTM training for dishwasher...
# Epoch 1/80: 100% 2025/2025 [00:05<00:00, 346.42it/s, loss=2.36e-6]
# Epoch 1/80, Train Loss: 0.000127, Val Loss: 0.000075, Val MAE: 101.87, Val SAE: 79.89, Val F1: 0.1865, Val Precision: 0.1055, Val Recall: 0.8071
# ...

# %%
# !python Sep-2026-House-3-scripts/test_lnn_refit_house3_dataset.py
# Out:
# Testing LiquidNetworkModel on APR-REFIT-House3-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House3-dataset
#   Train: 2015-02-10 00:00:00+00:00 to 2015-03-11 23:59:52+00:00  (324,000 rows)
#   Val: 2015-03-12 00:00:00+00:00 to 2015-03-18 23:59:52+00:00  (75,600 rows)
#   Test: 2015-03-19 00:00:00+00:00 to 2015-03-25 23:59:52+00:00  (75,600 rows)
#
# ...
# Testing LiquidNetworkModel on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting LiquidNetworkModel training for dishwasher...
# Epoch 1/80: 100% 2025/2025 [00:39<00:00, 51.31it/s, loss=4.78e-6]
# Epoch 1/80, Train Loss: 0.000158, Val Loss: 0.000065, Val MAE: 125.10, Val SAE: 104.77, Val F1: 0.2627, Val Precision: 0.1571, Val Recall: 0.8018
# ...

# %%
# Dual-head PINN + Gated-LNN
# !python Sep-2026-House-3-scripts/combined_pinn_lnn_refit_house3_dataset.py
# Out:
# Loading APR-REFIT-House3-dataset CSV data from '/content/REFIT-NILM/Sep-2026-House-3-scripts/../APR-REFIT-House3-dataset' ...
#   train : 324,000 rows  2015-02-10 -> 2015-03-11
#   val   :  75,600 rows  2015-03-12 -> 2015-03-18
#   test  :  75,600 rows  2015-03-19 -> 2015-03-25
#   Columns: ['aggregate', 'fridge', 'washing_machine', 'dishwasher', 'microwave']
#
# Device: cuda  |  WIN=299  hidden=64  dt=0.1
# Model: CombinedPINNAdvancedLNN  (gated power = gate x power)
#
#   Eval thresholds (W):
#   Appliance           Train      Val     Test
#   dishwasher           21.0     21.0     21.0
#   fridge               97.0     96.0     99.0
#   microwave            28.0     34.0     41.0
#   washing_machine      21.0     23.0     23.0
#
# Creating sequences ...
#   Train : (32371, 299, 8) -> (32371, 299, 4)  (9,678,929 predictions)
#   Val   : (7531, 299, 8) -> (7531, 299, 4)
#   Test  : (252, 299, 8) -> (252, 299, 4)  [non-overlapping]
#
#   Agg Z-score: mean=741.0 W  std=967.9 W
#
# ...
