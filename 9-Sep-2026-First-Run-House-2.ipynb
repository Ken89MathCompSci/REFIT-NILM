# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/REFIT-NILM/blob/master/9-Sep-2026-First-Run-House-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/REFIT-NILM
# Out:
# /content/REFIT-NILM

# %%
# %pwd
# Out:
# '/content/REFIT-NILM'

# %%
# SVM baseline (sklearn, no GPU needed, fastest of the bunch)
# !python Sep-2026-House-2-scripts/nilm_sfra_svm_house2.py
# Out:
# Loading APR-REFIT-House2-dataset from '/content/REFIT-NILM/Sep-2026-House-2-scripts/../APR-REFIT-House2-dataset' ...
#   train : 324,000 rows  2014-12-05 -> 2015-01-03
#   val   :  75,600 rows  2015-01-04 -> 2015-01-10
#   test  :  75,600 rows  2015-01-11 -> 2015-01-17
#
# Adaptive thresholds (train-locked):
#   dishwasher         43.0 W
#   fridge             21.0 W
#   microwave          43.0 W
#   washing_machine    25.0 W
#
# Computing features ...
#   Train: 324,000 samples -> using 20,000 for SVM
#   Test : 75,600 samples
#
#   [dishwasher]
#     Train ON%=7.8%  Test ON%=7.6%
#     class_weight: raw=11.7  clamped=10.0
#   [fridge]
#     Train ON%=32.4%  Test ON%=35.9%
#     class_weight: raw=2.1  clamped=2.1
#   [microwave]
#     Train ON%=0.4%  Test ON%=0.8%
#     class_weight: raw=252.2  clamped=10.0
#   [washing_machine]
#     Train ON%=2.5%  Test ON%=4.3%
#     class_weight: raw=38.7  clamped=10.0
#
# ...

# %%
# !python Sep-2026-House-2-scripts/test_gru_refit_house2_dataset.py
# Out:
# Testing GRU on APR-REFIT-House2-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House2-dataset
#   Train: 2014-12-05 00:00:00+00:00 to 2015-01-03 23:59:52+00:00  (324,000 rows)
#   Val: 2015-01-04 00:00:00+00:00 to 2015-01-10 23:59:52+00:00  (75,600 rows)
#   Test: 2015-01-11 00:00:00+00:00 to 2015-01-17 23:59:52+00:00  (75,600 rows)
#
# ...
# Testing GRU on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting GRU training for dishwasher...
# Epoch 1/80: 100% 2025/2025 [00:03<00:00, 523.33it/s, loss=0.00687]
# Epoch 1/80, Train Loss: 0.022827, Val Loss: 0.052738, Val MAE: 232.48, Val SAE: 202.44, Val F1: 0.2872, Val Precision: 0.1677, Val Recall: 0.9996
# ...

# %%
# !python Sep-2026-House-2-scripts/test_lnn_refit_house2_dataset.py
# Out:
# Testing LiquidNetworkModel on APR-REFIT-House2-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House2-dataset
#   Train: 2014-12-05 00:00:00+00:00 to 2015-01-03 23:59:52+00:00  (324,000 rows)
#   Val: 2015-01-04 00:00:00+00:00 to 2015-01-10 23:59:52+00:00  (75,600 rows)
#   Test: 2015-01-11 00:00:00+00:00 to 2015-01-17 23:59:52+00:00  (75,600 rows)
#
# ...
# Testing LiquidNetworkModel on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting LiquidNetworkModel training for dishwasher...
# Epoch 1/80: 100% 2025/2025 [00:38<00:00, 52.00it/s, loss=0.0992]
# Epoch 1/80, Train Loss: 0.021229, Val Loss: 0.043665, Val MAE: 211.23, Val SAE: 187.82, Val F1: 0.4529, Val Precision: 0.3046, Val Recall: 0.8828
# ...

# %%
# !python Sep-2026-House-2-scripts/test_lstm_refit_house2_dataset.py
# Out:
# Testing LSTM on APR-REFIT-House2-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House2-dataset
#   Train: 2014-12-05 00:00:00+00:00 to 2015-01-03 23:59:52+00:00  (324,000 rows)
#   Val: 2015-01-04 00:00:00+00:00 to 2015-01-10 23:59:52+00:00  (75,600 rows)
#   Test: 2015-01-11 00:00:00+00:00 to 2015-01-17 23:59:52+00:00  (75,600 rows)
#
# ...
# Testing LSTM on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting LSTM training for dishwasher...
# Epoch 1/80: 100% 2025/2025 [00:05<00:00, 346.71it/s, loss=0.0577]
# Epoch 1/80, Train Loss: 0.025063, Val Loss: 0.061505, Val MAE: 234.77, Val SAE: 214.90, Val F1: 0.6738, Val Precision: 0.5798, Val Recall: 0.8041
# ...

# %%
# Gated v2 models (adaptive per-appliance thresholds)
# !python Sep-2026-House-2-scripts/test_resnet_refit_house2_dataset_v2.py
# Out:
# Testing Gated ResNet v2 on APR-REFIT-House2-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House2-dataset
#   Train: 2014-12-05 00:00:00+00:00 to 2015-01-03 23:59:52+00:00  (324,000 rows)
#   Val: 2015-01-04 00:00:00+00:00 to 2015-01-10 23:59:52+00:00  (75,600 rows)
#   Test: 2015-01-11 00:00:00+00:00 to 2015-01-17 23:59:52+00:00  (75,600 rows)
#
#   Adaptive thresholds (train-locked, replaces the baseline scripts' uniform 10W):
#     dishwasher       43.0W
#     fridge           21.0W
#     microwave        43.0W
#     washing_machine  25.0W
#
# ...
# Testing Gated ResNet on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...  (threshold=43.0W)
#   Gate target: on=7.7%  pos_weight=12.0  thr_scaled=0.0183
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting Gated ResNet training for dishwasher...
# ...

# %%
# !python Sep-2026-House-2-scripts/test_tcn_refit_house2_dataset_v2.py
# Out:
# Testing Gated TCN v2 on APR-REFIT-House2-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House2-dataset
#   Train: 2014-12-05 00:00:00+00:00 to 2015-01-03 23:59:52+00:00  (324,000 rows)
#   Val: 2015-01-04 00:00:00+00:00 to 2015-01-10 23:59:52+00:00  (75,600 rows)
#   Test: 2015-01-11 00:00:00+00:00 to 2015-01-17 23:59:52+00:00  (75,600 rows)
#
#   Adaptive thresholds (train-locked, replaces the baseline scripts' uniform 10W):
#     dishwasher       43.0W
#     fridge           21.0W
#     microwave        43.0W
#     washing_machine  25.0W
#
# ...
# Testing Gated TCN on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...  (threshold=43.0W)
#   Gate target: on=7.7%  pos_weight=12.0  thr_scaled=0.0183
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting Gated TCN training for dishwasher...
# ...

# %%
# Dual-head PINN + Gated-LNN (ramp-epoch loss schedule)
# !python Sep-2026-House-2-scripts/combined_pinn_lnn_refit_house2_dataset.py
# Out:
# Loading APR-REFIT-House2-dataset CSV data from '/content/REFIT-NILM/Sep-2026-House-2-scripts/../APR-REFIT-House2-dataset' ...
#   train : 324,000 rows  2014-12-05 -> 2015-01-03
#   val   :  75,600 rows  2015-01-04 -> 2015-01-10
#   test  :  75,600 rows  2015-01-11 -> 2015-01-17
#   Columns: ['aggregate', 'fridge', 'washing_machine', 'dishwasher', 'microwave']
#
# Device: cuda  |  WIN=299  hidden=64  dt=0.1
# Model: CombinedPINNAdvancedLNN  (gated power = gate x power)
#
#   Eval thresholds (W):
#   Appliance           Train      Val     Test
#   dishwasher           43.0     47.0     43.0
#   fridge               21.0     21.0     21.0
#   microwave            43.0     57.0     47.0
#   washing_machine      25.0     25.0     25.0
#
# Creating sequences ...
#   Train : (32371, 299, 8) -> (32371, 299, 4)  (9,678,929 predictions)
#   Val   : (7531, 299, 8) -> (7531, 299, 4)
#   Test  : (252, 299, 8) -> (252, 299, 4)  [non-overlapping]
#
#   Agg Z-score: mean=621.2 W  std=1096.3 W
#
# ...
