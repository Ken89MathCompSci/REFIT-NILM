# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/REFIT-NILM/blob/master/20-July-2026-APR-testing-base-models-combined-LNN-results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/REFIT-NILM
# Out:
# /content/REFIT-NILM

# %%
# %pwd
# Out:
# '/content/REFIT-NILM'

# %%
# !python APR-REFIT-Scripts/test_lnn_refit_house2_dataset.py # 3. Individual models
# Out:
# Testing LiquidNetworkModel on APR-REFIT-House2-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House2-dataset
#   Train: 2014-03-20 00:00:00+00:00 to 2014-04-18 23:59:52+00:00  (324,000 rows)
#   Val: 2014-04-19 00:00:00+00:00 to 2014-04-25 23:59:52+00:00  (75,600 rows)
#   Test: 2014-04-26 00:00:00+00:00 to 2014-05-02 23:59:52+00:00  (75,600 rows)
#
# ...
# Testing LiquidNetworkModel on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting LiquidNetworkModel training for dishwasher...
# Epoch 1/80: 100% 2025/2025 [00:39<00:00, 51.00it/s, loss=0.00118]
# Epoch 1/80, Train Loss: 0.001435, Val Loss: 0.000765, Val MAE: 114.63, Val SAE: 103.72, Val F1: 0.0876, Val Precision: 0.0458, Val Recall: 1.0000
# ...

# %%
# !python APR-REFIT-Scripts/test_gru_refit_house2_dataset.py
# Out:
# Testing GRU on APR-REFIT-House2-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House2-dataset
#   Train: 2014-03-20 00:00:00+00:00 to 2014-04-18 23:59:52+00:00  (324,000 rows)
#   Val: 2014-04-19 00:00:00+00:00 to 2014-04-25 23:59:52+00:00  (75,600 rows)
#   Test: 2014-04-26 00:00:00+00:00 to 2014-05-02 23:59:52+00:00  (75,600 rows)
#
# ...
# Testing GRU on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting GRU training for dishwasher...
# Epoch 1/80: 100% 2025/2025 [00:03<00:00, 627.39it/s, loss=0.000227]
# Epoch 1/80, Train Loss: 0.001690, Val Loss: 0.000705, Val MAE: 75.11, Val SAE: 66.85, Val F1: 0.4405, Val Precision: 0.3741, Val Recall: 0.5355
# ...

# %%
# !python APR-REFIT-Scripts/test_lstm_refit_house2_dataset.py
# Out:
# Testing LSTM on APR-REFIT-House2-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House2-dataset
#   Train: 2014-03-20 00:00:00+00:00 to 2014-04-18 23:59:52+00:00  (324,000 rows)
#   Val: 2014-04-19 00:00:00+00:00 to 2014-04-25 23:59:52+00:00  (75,600 rows)
#   Test: 2014-04-26 00:00:00+00:00 to 2014-05-02 23:59:52+00:00  (75,600 rows)
#
# ...
# Testing LSTM on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting LSTM training for dishwasher...
# Epoch 1/80: 100% 2025/2025 [00:05<00:00, 349.12it/s, loss=0.00027]
# Epoch 1/80, Train Loss: 0.001986, Val Loss: 0.000965, Val MAE: 87.77, Val SAE: 80.14, Val F1: 0.0875, Val Precision: 0.0458, Val Recall: 1.0000
# ...

# %%
# !python APR-REFIT-Scripts/test_tcn_refit_house2_dataset.py
# Out:
# Testing TCN on APR-REFIT-House2-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House2-dataset
#   Train: 2014-03-20 00:00:00+00:00 to 2014-04-18 23:59:52+00:00  (324,000 rows)
#   Val: 2014-04-19 00:00:00+00:00 to 2014-04-25 23:59:52+00:00  (75,600 rows)
#   Test: 2014-04-26 00:00:00+00:00 to 2014-05-02 23:59:52+00:00  (75,600 rows)
#
# ...
# Testing TCN on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting TCN training for dishwasher...
# Epoch 1/80: 100% 2025/2025 [00:02<00:00, 713.32it/s, loss=9.45e-6]
# Epoch 1/80, Train Loss: 0.001018, Val Loss: 0.000600, Val MAE: 48.28, Val SAE: 38.43, Val F1: 0.4601, Val Precision: 0.3994, Val Recall: 0.5427
# ...

# %%
# !python APR-REFIT-Scripts/test_resnet_refit_house2_dataset.py
# Out:
# Testing ResNet on APR-REFIT-House2-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House2-dataset
#   Train: 2014-03-20 00:00:00+00:00 to 2014-04-18 23:59:52+00:00  (324,000 rows)
#   Val: 2014-04-19 00:00:00+00:00 to 2014-04-25 23:59:52+00:00  (75,600 rows)
#   Test: 2014-04-26 00:00:00+00:00 to 2014-05-02 23:59:52+00:00  (75,600 rows)
#
# ...
# Testing ResNet on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting ResNet training for dishwasher...
# Epoch 1/80: 100% 2025/2025 [00:06<00:00, 334.77it/s, loss=0.0048]
# Epoch 1/80, Train Loss: 0.004990, Val Loss: 0.000654, Val MAE: 49.30, Val SAE: 39.29, Val F1: 0.4144, Val Precision: 0.3466, Val Recall: 0.5152
# ...

# %%
# !python APR-REFIT-Scripts/test_transformer_refit_house2_dataset.py
# Out:
# Testing Transformer on APR-REFIT-House2-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House2-dataset
#   Train: 2014-03-20 00:00:00+00:00 to 2014-04-18 23:59:52+00:00  (324,000 rows)
#   Val: 2014-04-19 00:00:00+00:00 to 2014-04-25 23:59:52+00:00  (75,600 rows)
#   Test: 2014-04-26 00:00:00+00:00 to 2014-05-02 23:59:52+00:00  (75,600 rows)
#
# ...
# Testing Transformer on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting Transformer training for dishwasher...
# Epoch 1/80: 100% 2025/2025 [00:06<00:00, 305.65it/s, loss=0.000231]
# Epoch 1/80, Train Loss: 0.026963, Val Loss: 0.001010, Val MAE: 171.88, Val SAE: 151.09, Val F1: 0.4275, Val Precision: 0.4107, Val Recall: 0.4457
# ...

# %%
# !python APR-REFIT-Scripts/test_rf_refit_house2_dataset.py
# Out:
# Loading data from: /content/REFIT-NILM/APR-REFIT-House2-dataset
#   Train: 2014-03-20 00:00:00+00:00 to 2014-04-18 23:59:52+00:00  (324,000 rows)
#   Val: 2014-04-19 00:00:00+00:00 to 2014-04-25 23:59:52+00:00  (75,600 rows)
#   Test: 2014-04-26 00:00:00+00:00 to 2014-05-02 23:59:52+00:00  (75,600 rows)
#
# ...
# Training RandomForestRegressor on dishwasher
# ...
#
# Building windowed features for dishwasher...
#   Train: (64780, 10)  ON=8.22%
#   Val:   (15100, 10)  ON=4.58%
#   Test:  (15100, 10)  ON=7.97%
# Fitting RandomForestRegressor (300 trees) for dishwasher...
#   Val  -- F1=0.4514  P=0.3275  R=0.7265  MAE=21.20  SAE=19.2090
#   Test -- F1=0.4954  P=0.3842  R=0.6974  MAE=62.03  SAE=55.3632  TP=839  TN=12,552  FP=1,345  FN=364
#
# ...
# Training RandomForestRegressor on fridge
# ...
#
# Building windowed features for fridge...
#   Train: (64780, 10)  ON=36.27%
#   Val:   (15100, 10)  ON=32.93%
#   Test:  (15100, 10)  ON=37.43%
# Fitting RandomForestRegressor (300 trees) for fridge...
# ...

# %%
# !python APR-REFIT-Scripts/test_pinn_lnn_refit_house2_dataset.py
# Out:
# Loading data from: /content/REFIT-NILM/APR-REFIT-House2-dataset
#   Train: 2014-03-20 00:00:00+00:00 to 2014-04-18 23:59:52+00:00  (324,000 rows)
#   Val: 2014-04-19 00:00:00+00:00 to 2014-04-25 23:59:52+00:00  (75,600 rows)
#   Test: 2014-04-26 00:00:00+00:00 to 2014-05-02 23:59:52+00:00  (75,600 rows)
# Using device: cuda
# lambda_phys=0.01  epsilon=50.0 W  hidden=64  dt=0.1
# Thresholds: {'dishwasher': 10.0, 'fridge': 10.0, 'microwave': 10.0, 'washing_machine': 10.0}
# Train ON-rate:  {'dishwasher': 8.22, 'fridge': 36.27, 'microwave': 4.4, 'washing_machine': 4.69}
# MSE weights:    {'dishwasher': 1.0, 'fridge': 0.457, 'microwave': 1.312, 'washing_machine': 1.271}
# Train: (64780, 100, 1) -> (64780, 4)
# Val:   (15100, 100, 1) -> (15100, 4)
# Test:  (15100, 100, 1) -> (15100, 4)
# Model parameters: 9,028
# Starting PINN-LNN training (all appliances simultaneously)...
# ...

# %%
# !python APR-REFIT-Scripts/test_pinn_advanced_lnn_refit_house2_dataset.py
# Out:
# Loading data from: /content/REFIT-NILM/APR-REFIT-House2-dataset
#   Train: 2014-03-20 00:00:00+00:00 to 2014-04-18 23:59:52+00:00  (324,000 rows)
#   Val: 2014-04-19 00:00:00+00:00 to 2014-04-25 23:59:52+00:00  (75,600 rows)
#   Test: 2014-04-26 00:00:00+00:00 to 2014-05-02 23:59:52+00:00  (75,600 rows)
# Using device: cuda
# lambda_phys=0.01  epsilon=50.0 W  hidden=64  num_layers=2  dt=0.1
# Thresholds: {'dishwasher': 10.0, 'fridge': 10.0, 'microwave': 10.0, 'washing_machine': 10.0}
# Train: (64760, 200, 1) -> (64760, 4)
# Val:   (15080, 200, 1) -> (15080, 4)
# Test:  (15080, 200, 1) -> (15080, 4)
# Model parameters: 29,892
# Starting PINN-AdvancedLNN training (all appliances simultaneously)...
#   Epoch   1/80  train=0.60153 (mse=0.00390 phys=59.76236)  val=0.00237 (mse=0.00237 phys=0.00000)  avgF1=0.2351  avgMAE=724.09  lr=1.00e-03
#     dishwasher            F1=0.3573  P=0.3515  R=0.3632  MAE=101.20  SAE=95.7603
# ...

# %%
# 3. Individual models

# 4. Physics-informed models

# !python APR-REFIT-Scripts/combined_pinn_lnn_refit_house2_dataset.py
# Out:
# Loading APR-REFIT-House2-dataset CSV data from '/content/REFIT-NILM/APR-REFIT-Scripts/../APR-REFIT-House2-dataset' ...
#   train : 324,000 rows  2014-03-20 -> 2014-04-18
#   val   :  75,600 rows  2014-04-19 -> 2014-04-25
#   test  :  75,600 rows  2014-04-26 -> 2014-05-02
#   Columns: ['aggregate', 'fridge', 'washing_machine', 'dishwasher', 'microwave']
#
# Device: cuda  |  WIN=299  hidden=64  dt=0.1
# Model: CombinedPINNAdvancedLNN  (gated power = gate x power)
#
#   Eval thresholds (W):
#   Appliance           Train      Val     Test
#   dishwasher           43.0     43.0     43.0
#   fridge               21.0     21.0     21.0
#   microwave            56.0     42.0     46.4
#   washing_machine      25.0     25.0     25.0
#
# Creating sequences ...
#   Train : (32371, 299, 8) -> (32371, 299, 4)  (9,678,929 predictions)
#   Val   : (7531, 299, 8) -> (7531, 299, 4)
#   Test  : (252, 299, 8) -> (252, 299, 4)  [non-overlapping]
#
#   Agg Z-score: mean=389.7 W  std=1041.0 W
#
# ...
