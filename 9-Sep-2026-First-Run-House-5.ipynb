# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/REFIT-NILM/blob/master/9-Sep-2026-First-Run-House-5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/REFIT-NILM
# Out:
# /content/REFIT-NILM

# %%
# %pwd
# Out:
# '/content/REFIT-NILM'

# %%
# SVM baseline
# !python Sep-2026-House-5-scripts/nilm_sfra_svm_house5.py
# Out:
# Loading APR-REFIT-House5-dataset from '/content/REFIT-NILM/Sep-2026-House-5-scripts/../APR-REFIT-House5-dataset' ...
#   train : 324,000 rows  2014-08-15 -> 2014-09-13
#   val   :  75,600 rows  2014-09-14 -> 2014-09-20
#   test  :  75,600 rows  2014-09-21 -> 2014-09-27
#
# Adaptive thresholds (train-locked):
#   dishwasher         24.0 W
#   fridge             22.0 W
#   microwave          21.0 W
#   washing_machine    23.0 W
#
# Computing features ...
#   Train: 324,000 samples -> using 20,000 for SVM
#   Test : 75,600 samples
#
#   [dishwasher]
#     Train ON%=7.0%  Test ON%=8.8%
#     class_weight: raw=13.3  clamped=10.0
#   [fridge]
#     Train ON%=53.5%  Test ON%=56.3%
#     class_weight: raw=0.9  clamped=1.0
#   [microwave]
#     Train ON%=1.7%  Test ON%=2.5%
#     class_weight: raw=56.3  clamped=10.0
#   [washing_machine]
#     Train ON%=13.5%  Test ON%=14.9%
#     class_weight: raw=6.4  clamped=6.4
#
# ...

# %%
# Baselines (uniform 10W threshold)
# !python Sep-2026-House-5-scripts/test_gru_refit_house5_dataset.py
# Out:
# Testing GRU on APR-REFIT-House5-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House5-dataset
#   Train: 2014-08-15 00:00:00+00:00 to 2014-09-13 23:59:52+00:00  (324,000 rows)
#   Val: 2014-09-14 00:00:00+00:00 to 2014-09-20 23:59:52+00:00  (75,600 rows)
#   Test: 2014-09-21 00:00:00+00:00 to 2014-09-27 23:59:52+00:00  (75,600 rows)
#
# ...
# Testing GRU on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting GRU training for dishwasher...
# Epoch 1/80: 100% 2025/2025 [00:03<00:00, 537.96it/s, loss=0.000122]
# Epoch 1/80, Train Loss: 0.012909, Val Loss: 0.015898, Val MAE: 89.00, Val SAE: 84.45, Val F1: 0.1385, Val Precision: 0.0744, Val Recall: 1.0000
# ...

# %%
# !python Sep-2026-House-5-scripts/test_lnn_refit_house5_dataset.py
# Out:
# Testing LiquidNetworkModel on APR-REFIT-House5-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House5-dataset
#   Train: 2014-08-15 00:00:00+00:00 to 2014-09-13 23:59:52+00:00  (324,000 rows)
#   Val: 2014-09-14 00:00:00+00:00 to 2014-09-20 23:59:52+00:00  (75,600 rows)
#   Test: 2014-09-21 00:00:00+00:00 to 2014-09-27 23:59:52+00:00  (75,600 rows)
#
# ...
# Testing LiquidNetworkModel on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting LiquidNetworkModel training for dishwasher...
# Epoch 1/80: 100% 2025/2025 [00:39<00:00, 51.47it/s, loss=0.0134]
# Epoch 1/80, Train Loss: 0.012133, Val Loss: 0.015024, Val MAE: 84.64, Val SAE: 75.28, Val F1: 0.1350, Val Precision: 0.0735, Val Recall: 0.8299
# ...

# %%
# !python Sep-2026-House-5-scripts/test_lstm_refit_house5_dataset.py
# Out:
# Testing LSTM on APR-REFIT-House5-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House5-dataset
#   Train: 2014-08-15 00:00:00+00:00 to 2014-09-13 23:59:52+00:00  (324,000 rows)
#   Val: 2014-09-14 00:00:00+00:00 to 2014-09-20 23:59:52+00:00  (75,600 rows)
#   Test: 2014-09-21 00:00:00+00:00 to 2014-09-27 23:59:52+00:00  (75,600 rows)
#
# ...
# Testing LSTM on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting LSTM training for dishwasher...
# Epoch 1/80: 100% 2025/2025 [00:05<00:00, 347.92it/s, loss=0.000203]
# Epoch 1/80, Train Loss: 0.013136, Val Loss: 0.016602, Val MAE: 85.57, Val SAE: 82.30, Val F1: 0.1384, Val Precision: 0.0744, Val Recall: 1.0000
# ...

# %%
# Gated v2 models (adaptive thresholds: dishwasher=24W, fridge=22W, microwave=21W, washing_machine=23W)
# !python Sep-2026-House-5-scripts/test_resnet_refit_house5_dataset_v2.py
# Out:
# Testing Gated ResNet v2 on APR-REFIT-House5-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House5-dataset
#   Train: 2014-08-15 00:00:00+00:00 to 2014-09-13 23:59:52+00:00  (324,000 rows)
#   Val: 2014-09-14 00:00:00+00:00 to 2014-09-20 23:59:52+00:00  (75,600 rows)
#   Test: 2014-09-21 00:00:00+00:00 to 2014-09-27 23:59:52+00:00  (75,600 rows)
#
#   Adaptive thresholds (train-locked, replaces the baseline scripts' uniform 10W):
#     dishwasher       24.0W
#     fridge           22.0W
#     microwave        21.0W
#     washing_machine  23.0W
#
# ...
# Testing Gated ResNet on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...  (threshold=24.0W)
#   Gate target: on=7.0%  pos_weight=13.3  thr_scaled=0.0094
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting Gated ResNet training for dishwasher...
# ...

# %%
# !python Sep-2026-House-5-scripts/test_tcn_refit_house5_dataset_v2.py
# Out:
# Testing Gated TCN v2 on APR-REFIT-House5-dataset...
# Loading data from: /content/REFIT-NILM/APR-REFIT-House5-dataset
#   Train: 2014-08-15 00:00:00+00:00 to 2014-09-13 23:59:52+00:00  (324,000 rows)
#   Val: 2014-09-14 00:00:00+00:00 to 2014-09-20 23:59:52+00:00  (75,600 rows)
#   Test: 2014-09-21 00:00:00+00:00 to 2014-09-27 23:59:52+00:00  (75,600 rows)
#
#   Adaptive thresholds (train-locked, replaces the baseline scripts' uniform 10W):
#     dishwasher       24.0W
#     fridge           22.0W
#     microwave        21.0W
#     washing_machine  23.0W
#
# ...
# Testing Gated TCN on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...  (threshold=24.0W)
#   Gate target: on=7.0%  pos_weight=13.3  thr_scaled=0.0094
# Training sequences:   (64780, 100, 1) -> (64780, 1)
# Validation sequences: (15100, 100, 1) -> (15100, 1)
# Test sequences:       (15100, 100, 1) -> (15100, 1)
# Starting Gated TCN training for dishwasher...
# ...

# %%
# Dual-head PINN + Gated-LNN (this is the one to watch for the microwave test)
# !python Sep-2026-House-5-scripts/combined_pinn_lnn_refit_house5_dataset.py
# Out:
# Loading APR-REFIT-House5-dataset CSV data from '/content/REFIT-NILM/Sep-2026-House-5-scripts/../APR-REFIT-House5-dataset' ...
#   train : 324,000 rows  2014-08-15 -> 2014-09-13
#   val   :  75,600 rows  2014-09-14 -> 2014-09-20
#   test  :  75,600 rows  2014-09-21 -> 2014-09-27
#   Columns: ['aggregate', 'fridge', 'washing_machine', 'dishwasher', 'microwave']
#
# Device: cuda  |  WIN=299  hidden=64  dt=0.1
# Model: CombinedPINNAdvancedLNN  (gated power = gate x power)
#
#   Eval thresholds (W):
#   Appliance           Train      Val     Test
#   dishwasher           24.0     24.0     24.0
#   fridge               22.0     22.0     22.0
#   microwave            21.0     21.0     21.0
#   washing_machine      23.0     23.0     23.0
#
# Creating sequences ...
#   Train : (32371, 299, 8) -> (32371, 299, 4)  (9,678,929 predictions)
#   Val   : (7531, 299, 8) -> (7531, 299, 4)
#   Test  : (252, 299, 8) -> (252, 299, 4)  [non-overlapping]
#
#   Agg Z-score: mean=793.8 W  std=713.6 W
#
# ...
